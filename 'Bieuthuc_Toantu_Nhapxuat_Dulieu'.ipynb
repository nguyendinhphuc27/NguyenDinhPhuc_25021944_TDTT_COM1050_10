# %%
#W2A1
print('Hello world!')
# Out:
# Hello world!

# %%
#W2A2
name=input('Mời nhập tên của bạn:')
print('Xin chào bạn',name,sep=' ')
# Out:
# Mời nhập tên của bạn: Nguyễn Đình Phúc
# Xin chào bạn Nguyễn Đình Phúc

# %%
#W2A3
a, b=map(int,input().split( ))
print(f'{a}+{b}={a+b}')
print(f'{a}-{b}={a-b}')
print(f'{a}*{b}={a*b}')
print(f'{a}/{b}={a/b:.2f}')
print(f'{a}//{b}={a//b}')
print(f'{a}%{b}={a%b}')
# Out:
#  30 12
# 30+12=42
# 30-12=18
# 30*12=360
# 30/12=2.50
# 30//12=2
# 30%12=6

# %%
#W2A4
a1,b1,c1,a2,b2,a3= map(int,input().split( ))
print('Điểm tb của hsinh là:',(a1+b1+c1+(a2+b2)*2+a3*3)/10)
# Out:
#  10 9 10 10 9 9
# Điểm tb của hsinh là: 9.4

# %%
#W2A5
a, b=map(int,input().split())
print(a**b)
# Out:
#  3 4
# 81

# %%
#W2A6
i='a'
b=17
print(chr(b), ord(i))
# Out:
#  97

# %%
#W2A7
print(f'({13}**{2})*{3}+{5}={(13**2)*3+5}')
print(f'{13}**{2}*{3}+{5}={13**2*3+5}')
# Out:
# (13**2)*3+5=512
# 13**2*3+5=512

# %%
#W2A8
cel=int(input('Nhiệt độ C hiện tại là:'))
print('Nhiệt độ hiện tại theo độ F là:', f'{cel*9/5+32:.2f}')
# Out:
# Nhiệt độ C hiện tại là: 35
# Nhiệt độ hiện tại theo độ F là: 95.00

# %%
#W2A9
cost= int(input('Số tiền của chiêc đồng hồ là:'))
print('Gía phải trả cho chiếc đồng hồ là:',f'{cost+10+cost*0.3+cost*0.1 :.2f}')
# Out:
# Số tiền của chiêc đồng hồ là: 1500
# Gía phải trả cho chiếc đồng hồ là: 2110.00

# %%
#W2A10
a, b, c= input().split()
print('Xin chào bạn',c ,',' ,b ,'and' ,a)
# Out:
#  đức huy đạt
# Xin chào bạn đạt , huy and đức

# %%
#W2A11
h, m= map(int,input('Mời nhập số giờ và số phút:').split())
print('Số giờ sang giây là',f'{h*3600}',end='_')
print('Số phút đổi sang giây là',f'{m*60}')
# Out:
# Mời nhập số giờ và số phút: 19 21
# Số giờ sang giây là 68400_Số phút đổi sang giây là 1260

# %%
#W2A12
n=int(input('Mời bạn nhập độ dài cạnh rubik:'))
print('Số miếng dán cần dùng là:',n**2*6)
# Out:
# Mời bạn nhập độ dài cạnh rubik: 3
# Số miếng dán cần dùng là: 54

# %%
#W2A13
a, b= map(int,input().split())
c=(a*b) %10
print('Hàng đơn vị của tích giữa a, b là:',c)
# Out:
#  19 28
# Hàng đơn vị của tích giữa a, b là: 2

# %%
#W2A14
a,b= map(int,input().split())
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
#  20 10
# 10 20

# %%
#W2A15
'''số sao có cthuc là A=6*n*(n-1)+1'''
n=int(input())
A=6*n*(n-1)+1
print('Số sao thứ n là:',A)
# Out:
#  3
# Số sao thứ n là: 37

# %%
#W2A16
print('Spring','Summer','Autumn','Winter',sep='\n')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print('  *',' ***','*****',sep='\n')
# Out:
#   *
#  ***
# *****

# %%
#W2A18
num=['### # #  ### ###',' #  #  #  #  #',' #  #   # #  #',' #  #  #  #  #',' #  ##    #  #']
for i in num:
    print(i)
# Out:
# ### # #  ### ###
#  #  #  #  #  #
#  #  #   # #  #
#  #  #  #  #  #
#  #  ##    #  #

# %%
#W2A19
days=['monday','tuesday','wednesday','thursday','friday','saturday','sunday']
for i in days:
    print(i)
# Out:
# monday
# tuesday
# wednesday
# thursday
# friday
# saturday
# sunday

# %%
#W2A20
months=['january','february','march','april','may','june','july','august','september','october','november','december']
for i in months:
    print(i)
# Out:
# january
# february
# march
# april
# may
# june
# july
# august
# september
# october
# november
# december

# %%
#W2A21
for i in range(10):
    i+=1   #dòng này có hay kh cũng kh ảnh hưởng
    print('Hello world!')
# Out:
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
# Hello world!
